# %%
# import pandas as pd 
import matplotlib.pyplot as plt

# %%
data= [-1,7,3,2,10]
data1 = [1,2,3,4,5]
plt.plot(data, 'gs-',
         data1,'^-')
#設定座標軸標籤及標題

# 直方圖
data2= [-5,6,9,7,30]
n,bins,patches = plt.hist(data2,3)
n,bins
#圓餅圖
data =[2,8,1,3,6]
labels=['a','b','c','d','e']
#patches,text =plt.pie(data,labels=labels,explode =explode,)
#plt.legend(patches, labels, loc='best')
#plt.axis('equal')
#子圖
plt.subplot(2,1,1)#2 上一張
plt.plot(data)
plt.subplot
# Out:
# <function matplotlib.pyplot.subplot(*args, **kwargs)>

# %%
plt.rcParams['font.sans-serif']=['Microsoft JhengHei']
plt.rcParams['axes.unicode_minus']=False
#無法出現

# %%
data1= [-1,7,3,2,10]
data1 = [1,2,3,4,5]
plt.plot(data, 'gs-',
         data1,'^-')
plt.xlabel('x軸')
plt.ylabel('y軸')
plt.title('標題')
# Out:
# Text(0.5, 1.0, '標題')

# %%
data = [-5,6,9,7,30]
plt.plot(data,'gs-', label='data')
plt.plot(data1,'^-',label='data1')
plt.legend(loc ='upper left')

# %%
plt.plot(data,'gs-', label='data')
plt.plot(data1,'^-',label='data1')
plt.legend(loc ='upper left')
plt.axis()
plt.axis([0,3,-4,15])
# Out:
# [0, 3, -4, 15]

# %%
plt.plot(data,'gs-', label='data')
plt.plot(data1,'^-',label='data1')
plt.legend(loc ='upper left')
plt.savefig('example.png')

# %%
plt.scatter(data,data1)

# %%
import numpy as np
color = np.random.rand(5)
size = np.random.rand(5)*50
plt.scatter(data,data1,size,color)
plt.colorbar()

# %%
import pandas as pd
df=pd.read_csv('opendata108N010.csv')
#更新欄位名稱

#刪除第一列
df.columns =['統計年','區域別','年底人口數','土地面積','人口密度']
df.drop(index=0,inplace=True)
df.drop(index=range(369,375),inplace=True)
print(df)
df.fillna(0)
print(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-cee4d6416657> in <module>
# ----> 1 import pandas as pd
#       2 df=pd.read_csv('opendata108N010.csv')
#       3 #更新欄位名稱
#       4
#       5 #刪除第一列
#
# C:\ProgramData\Anaconda3\envs\MyProject\lib\site-packages\pandas\__init__.py in <module>
#      53 import pandas.core.config_init
#      54
# ---> 55 from pandas.core.api import (
#      56     # dtype
#      57     Int8Dtype,
#
# C:\ProgramData\Anaconda3\envs\MyProject\lib\site-packages\pandas\core\api.py in <module>
#      27 from pandas.core.arrays.string_ import StringDtype
#      28 from pandas.core.construction import array
# ---> 29 from pandas.core.groupby import Grouper, NamedAgg
#      30 from pandas.core.indexes.api import (
#      31     CategoricalIndex,
#
# ...

# %%
print(df['區域別'])

# %%
df['縣市']=df['區域別'].str[:3] #取縣市
print(df)
df['區域']=df['區域別'].str[3:]
city_group = df.groupby('縣市')
taipei = city_group.get_group('臺北市')
taipei.index =taipei['區域']

# %%
import plotly.graph_objects as go
import plotly.express as px

# %%
import pandas as pd 
token= open(".mapboxToken").read() #.隱藏資料夾
px.set_mapbox_access_token(token)
fig =go.Figure(go.Scattermapbox(
    mode="markers+text+lines",lon=[-75,-80,-50],lat=[45,20,-20],
    marker={'size':20,'symbol':["bus","habor","airpot"]},
    text =["bus","habor","airpot"], textposition="bottom right"))
